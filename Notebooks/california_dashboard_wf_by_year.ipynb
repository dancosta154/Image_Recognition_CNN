# %%
import pandas as pd

# %%
# Data pulled from https://www.iii.org/table-archive/23284
# I don't remember what notebook has the scrapers for these .xls files... but it's super easy to replicate if we want them for any reason

# %%
df_list = pd.read_html('../Data/Wildfires By State, 2016.xls')
df = pd.DataFrame(df_list[0])
df.head(10)
# Out:
#                                                State  Number of fires  \
# 0  Wildfires By State, 2016 State Number of fires...              NaN
# 1                           Wildfires By State, 2016              NaN
# 2                                                NaN              NaN
# 3  State Number of fires Number of acres burned A...              NaN
# 4                                              State  Number of fires
# 5                                             Alaska              572
# 6                                            Alabama             3923
# 7                                            Arizona             2288
# 8                                           Arkansas             1513
# 9                                         California             7349
#
#    Number of acres burned
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4  Number of acres burned
# 5                  496467
# ...

# %%
df.drop([0, 1, 2, 3, 4], inplace=True)

# %%
df.head()
# Out:
#         State Number of fires Number of acres burned
# 5      Alaska             572                 496467
# 6     Alabama            3923                  59030
# 7     Arizona            2288                 308245
# 8    Arkansas            1513                  33371
# 9  California            7349                 560815

# %%
wf_2021 = pd.read_csv('../Data/dashboard/wildfires_by_state_2021.csv')
wf_2021
# Out:
#                    state  num_fires  num_acres_burned
# 0                Alabama       1040             22055
# 1                 Alaska        384            253357
# 2                Arizona       1773            524428
# 3               Arkansas        378             17003
# 4             California       9260           2233666
# 5               Colorado       1017             48195
# 6            Connecticut         60               127
# 7               Delaware          0                 0
# 8   District of Columbia          0                 0
# 9                Florida       2262            105475
# 10               Georgia       2139             11108
# 11                Hawaii          1             40000
# 12                 Idaho       1332            439600
# 13              Illinois         29               219
# 14               Indiana         34               836
# 15                  Iowa        187              7950
# ...

# %%
wf_2021.drop(52, inplace=True)

# %%
wf_2021
# Out:
#                    state  num_fires  num_acres_burned
# 0                Alabama       1040             22055
# 1                 Alaska        384            253357
# 2                Arizona       1773            524428
# 3               Arkansas        378             17003
# 4             California       9260           2233666
# 5               Colorado       1017             48195
# 6            Connecticut         60               127
# 7               Delaware          0                 0
# 8   District of Columbia          0                 0
# 9                Florida       2262            105475
# 10               Georgia       2139             11108
# 11                Hawaii          1             40000
# 12                 Idaho       1332            439600
# 13              Illinois         29               219
# 14               Indiana         34               836
# 15                  Iowa        187              7950
# ...

# %%
wf_2021.to_csv('../Data/dashboard/wildfires_by_state_2021.csv', index=False)

# %%
wf_2021
# Out:
#                    state  num_fires  num_acres_burned
# 0                Alabama       1040             22055
# 1                 Alaska        384            253357
# 2                Arizona       1773            524428
# 3               Arkansas        378             17003
# 4             California       9260           2233666
# 5               Colorado       1017             48195
# 6            Connecticut         60               127
# 7               Delaware          0                 0
# 8   District of Columbia          0                 0
# 9                Florida       2262            105475
# 10               Georgia       2139             11108
# 11                Hawaii          1             40000
# 12                 Idaho       1332            439600
# 13              Illinois         29               219
# 14               Indiana         34               836
# 15                  Iowa        187              7950
# ...
